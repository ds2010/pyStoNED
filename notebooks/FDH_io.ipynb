# %% [markdown]
# ## FDH: Input orientation

# %% [markdown]
# The FDH estimator was first proposed by Deprins et al. (1984), and the mixed
# integer linear program (MILP) formulation of FDH was introduced by Tulkens (1993).
#
# Given the input variables $X = [x_1, x_2, \cdots, x_n]$ and output variables $Y = [y_1, y_2, \cdots, y_n]$,
# we measure the input oriented efficiency for observation :math:`i` by solving the following MILP problem:
#     \begin{align*}
#             \underset{\mathbf{\phi},\mathbf{\lambda}}min \quad \phi_i \\
#             \mbox{s.t.} \quad
#             X\lambda \le \phi_i x_i  \\
#             Y\lambda \ge y_i  \\
#             \sum \lambda = 1 \\
#             \lambda_j \in \{0, 1\} &{}& \forall j
#     \end{align*}
#
# where $\lambda = [\lambda_1, \lambda_2, \cdots, \lambda_n]$ is the vector of intensity weights. The efficiency
# of observation $i$ is $\phi^*_i$. The corresponding calculation processes are as follow:

# %%
# import packages
from pystoned import FDH
from pystoned import dataset as dataset
from pystoned.constant import ORIENT_IO, OPT_LOCAL

# %%
# import the data provided with Tim Coelli’s Frontier 4.1
data = dataset.load_Tim_Coelli_frontier()

# %%
# define and solve the FDH model
model = FDH.FDH(data.y, data.x, orient=ORIENT_IO)
model.optimize(OPT_LOCAL)
# Out:
# Optimizing locally.
# Estimating the additive model locally with mosek solver
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 240
#   Cones                  : 0
#   Scalar variables       : 3660
#   Matrix variables       : 0
#   Integer variables      : 3600
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 4
# Presolve started.
# Presolve terminated. Time = 0.11
# Presolved problem: 1885 variables, 231 constraints, 7364 non-zeros
# Presolved problem: 0 general integer, 1827 binary, 58 continuous
# Clique table size: 58
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# 0        0        1        0        1.1778948068e+04     NA                   NA          0.1
# 0        1        1        0        1.1778948068e+04     4.9245315527e+01     99.58       0.2
# 0        1        1        0        5.1628322950e+01     4.9245315527e+01     4.62        0.2
# Cut generation started.
# 0        1        1        0        5.1628322950e+01     4.9245315527e+01     4.62        0.2
# 0        2        1        0        5.1628322950e+01     5.1042876901e+01     1.13        0.2
# Cut generation terminated. Time = 0.02
# 0        4        1        0        5.1043883620e+01     5.1043328215e+01     1.09e-03    0.2
# An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# The relative gap is 1.09e-03(%).
#
# Objective of best integer solution : 5.104388361964e+01
# Best objective bound               : 5.104332821483e+01
# Construct solution objective       : Not employed
# User objective cut value           : Not employed
# Number of cuts generated           : 60
#   Number of Gomory cuts            : 30
#   Number of CMIR cuts              : 30
# Number of branches                 : 0
# Number of relaxations solved       : 4
# Number of interior point iterations: 23
# Number of simplex iterations       : 46
# Time spend presolving the root     : 0.11
# Time spend optimizing the root     : 0.02
# Mixed integer optimizer terminated. Time: 0.23
#
# Optimizer terminated. Time: 0.27
#
#
# Integer solution solution summary
#   Problem status  : PRIMAL_FEASIBLE
#   Solution status : INTEGER_OPTIMAL
#   Primal.  obj: 5.1043883620e+01    nrm: 4e+01    Viol.  con: 1e-14    var: 4e-16    itg: 7e-16

# %%
# display the technical efficiency
model.display_theta()
# Out:
# theta : efficiency
#     Size=60, Index=I
#     Key : Lower : Value               : Upper : Fixed : Stale : Domain
#       0 :  None :  0.7592395921835173 :  None : False : False :  Reals
#       1 :  None :  0.8686194270945511 :  None : False : False :  Reals
#       2 :  None :  0.7674472989676945 :  None : False : False :  Reals
#       3 :  None :   0.862485293293742 :  None : False : False :  Reals
#       4 :  None :  0.7559940346449466 :  None : False : False :  Reals
#       5 :  None :                 1.0 :  None : False : False :  Reals
#       6 :  None :                 1.0 :  None : False : False :  Reals
#       7 :  None :  0.6712148530773353 :  None : False : False :  Reals
#       8 :  None :                 1.0 :  None : False : False :  Reals
#       9 :  None :                 1.0 :  None : False : False :  Reals
#      10 :  None :                 1.0 :  None : False : False :  Reals
#      11 :  None :                 1.0 :  None : False : False :  Reals
#      12 :  None :  0.4210173663339259 :  None : False : False :  Reals
#      13 :  None :  0.8666491320357707 :  None : False : False :  Reals
#      14 :  None :                 1.0 :  None : False : False :  Reals
#      15 :  None :  0.6487704918032786 :  None : False : False :  Reals
#      16 :  None :  0.8518565454315044 :  None : False : False :  Reals
#      17 :  None :  0.9495962741477665 :  None : False : False :  Reals
#      18 :  None :                 1.0 :  None : False : False :  Reals
#      19 :  None :  0.9594594594594593 :  None : False : False :  Reals
#      20 :  None :  0.8950969343032454 :  None : False : False :  Reals
#      21 :  None :                 1.0 :  None : False : False :  Reals
#      22 :  None :                 1.0 :  None : False : False :  Reals
#      23 :  None :                 1.0 :  None : False : False :  Reals
#      24 :  None :                 1.0 :  None : False : False :  Reals
#      25 :  None :                 1.0 :  None : False : False :  Reals
#      26 :  None :  0.6863407038305823 :  None : False : False :  Reals
#      27 :  None :  0.8327987812211843 :  None : False : False :  Reals
#      28 :  None :                 1.0 :  None : False : False :  Reals
#      29 :  None :  0.9285769618095903 :  None : False : False :  Reals
#      30 :  None :                 1.0 :  None : False : False :  Reals
#      31 :  None :                 1.0 :  None : False : False :  Reals
#      32 :  None :                 1.0 :  None : False : False :  Reals
#      33 :  None :    0.45020398017225 :  None : False : False :  Reals
#      34 :  None : 0.39038224414303335 :  None : False : False :  Reals
#      35 :  None :  0.8019486975541859 :  None : False : False :  Reals
#      36 :  None :  0.5813752342511173 :  None : False : False :  Reals
#      37 :  None :  0.7997620464009519 :  None : False : False :  Reals
#      38 :  None :  0.7810627247303237 :  None : False : False :  Reals
#      39 :  None :                 1.0 :  None : False : False :  Reals
#      40 :  None :                 1.0 :  None : False : False :  Reals
#      41 :  None :  0.8228688005070511 :  None : False : False :  Reals
#      42 :  None :   0.823733660130719 :  None : False : False :  Reals
#      43 :  None :                 1.0 :  None : False : False :  Reals
#      44 :  None :  0.7191184756975603 :  None : False : False :  Reals
#      45 :  None :  0.8388459023539669 :  None : False : False :  Reals
#      46 :  None :  0.6168935865281261 :  None : False : False :  Reals
#      47 :  None :                 1.0 :  None : False : False :  Reals
#      48 :  None :  0.6155583989763685 :  None : False : False :  Reals
#      49 :  None :  0.7076890034364262 :  None : False : False :  Reals
#      50 :  None :                 1.0 :  None : False : False :  Reals
#      51 :  None :  0.9033315844700944 :  None : False : False :  Reals
#      52 :  None :   0.585137905032976 :  None : False : False :  Reals
#      53 :  None :  0.7831959706959708 :  None : False : False :  Reals
#      54 :  None :                 1.0 :  None : False : False :  Reals
#      55 :  None :  0.8558336051695481 :  None : False : False :  Reals
#      56 :  None :                 1.0 :  None : False : False :  Reals
#      57 :  None :  0.6323860245167806 :  None : False : False :  Reals
#      58 :  None :   0.913092475969506 :  None : False : False :  Reals
#      59 :  None :  0.6963001492604821 :  None : False : False :  Reals

# %%
# display the intensity variables
model.display_lamda()
# Out:
# lamda : intensity variables
#     Size=3600, Index=lamda_index
#     Key      : Lower : Value                   : Upper : Fixed : Stale : Domain
#       (0, 0) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 1) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 2) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 3) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 4) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 5) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 6) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 7) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 8) :     0 :                     0.0 :     1 : False : False : Binary
#       (0, 9) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 10) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 11) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 12) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 13) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 14) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 15) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 16) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 17) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 18) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 19) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 20) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 21) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 22) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 23) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 24) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 25) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 26) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 27) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 28) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 29) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 30) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 31) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 32) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 33) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 34) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 35) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 36) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 37) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 38) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 39) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 40) :     0 :                     1.0 :     1 : False : False : Binary
#      (0, 41) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 42) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 43) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 44) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 45) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 46) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 47) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 48) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 49) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 50) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 51) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 52) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 53) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 54) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 55) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 56) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 57) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 58) :     0 :                     0.0 :     1 : False : False : Binary
#      (0, 59) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 0) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 1) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 2) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 3) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 4) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 5) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 6) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 7) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 8) :     0 :                     0.0 :     1 : False : False : Binary
#       (1, 9) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 10) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 11) :     0 :      0.9999999999999998 :     1 : False : False : Binary
#      (1, 12) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 13) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 14) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 15) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 16) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 17) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 18) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 19) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 20) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 21) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 22) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 23) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 24) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 25) :     0 :   2.583165862343199e-16 :     1 : False : False : Binary
#      (1, 26) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 27) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 28) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 29) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 30) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 31) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 32) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 33) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 34) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 35) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 36) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 37) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 38) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 39) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 40) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 41) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 42) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 43) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 44) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 45) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 46) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 47) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 48) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 49) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 50) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 51) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 52) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 53) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 54) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 55) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 56) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 57) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 58) :     0 :                     0.0 :     1 : False : False : Binary
#      (1, 59) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 0) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 1) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 2) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 3) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 4) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 5) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 6) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 7) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 8) :     0 :                     0.0 :     1 : False : False : Binary
#       (2, 9) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 10) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 11) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 12) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 13) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 14) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 15) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 16) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 17) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 18) :     0 :                     1.0 :     1 : False : False : Binary
#      (2, 19) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 20) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 21) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 22) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 23) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 24) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 25) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 26) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 27) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 28) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 29) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 30) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 31) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 32) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 33) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 34) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 35) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 36) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 37) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 38) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 39) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 40) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 41) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 42) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 43) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 44) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 45) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 46) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 47) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 48) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 49) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 50) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 51) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 52) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 53) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 54) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 55) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 56) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 57) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 58) :     0 :                     0.0 :     1 : False : False : Binary
#      (2, 59) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 0) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 1) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 2) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 3) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 4) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 5) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 6) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 7) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 8) :     0 :                     0.0 :     1 : False : False : Binary
#       (3, 9) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 10) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 11) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 12) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 13) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 14) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 15) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 16) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 17) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 18) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 19) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 20) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 21) :     0 :      1.0000000000000002 :     1 : False : False : Binary
#      (3, 22) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 23) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 24) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 25) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 26) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 27) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 28) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 29) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 30) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 31) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 32) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 33) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 34) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 35) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 36) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 37) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 38) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 39) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 40) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 41) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 42) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 43) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 44) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 45) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 46) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 47) :     0 :  -1.442850722756614e-16 :     1 : False : False : Binary
#      (3, 48) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 49) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 50) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 51) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 52) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 53) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 54) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 55) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 56) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 57) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 58) :     0 :                     0.0 :     1 : False : False : Binary
#      (3, 59) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 0) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 1) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 2) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 3) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 4) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 5) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 6) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 7) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 8) :     0 :                     0.0 :     1 : False : False : Binary
#       (4, 9) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 10) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 11) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 12) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 13) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 14) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 15) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 16) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 17) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 18) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 19) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 20) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 21) :     0 :  1.1580050719956238e-16 :     1 : False : False : Binary
#      (4, 22) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 23) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 24) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 25) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 26) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 27) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 28) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 29) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 30) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 31) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 32) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 33) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 34) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 35) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 36) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 37) :     0 :                     0.0 :     1 : False : False : Binary
#      (4, 38) :     0 :                     0.0 :     1 : False : False : Binary
#      (4,